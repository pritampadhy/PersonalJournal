# %%
! pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 50.0 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.81.94.8

# %%
import streamlit as st
st.write('# Streamlit calculator')
number1= st.number_input('number 1')
number2 = st.number_input('number 2')
num3 = number1+number2
st.write('# Answer is ',num3)
# Out:
# Writing app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# /bin/bash: line 1: streamlit: command not found
# ⠙⠹⠸⠼⠴your url is: https://dark-terms-join.loca.lt
